# %%
import os
from influence_moo.config import load_config

# %%
config_dirs = []

top_dir = "/home/gonzaeve/influence-multi-objective/results/captain_c/observations"
for dirpath, _, filenames in os.walk(top_dir):
    for filename in filenames:
        if filename == 'config.yaml':
            config_dir = dirpath+'/config.yaml'
            config_dirs.append(config_dir)

# %%
for c in config_dirs:
    print(c)
# Out:
# /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/D-Indirect/config.yaml
# /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/D/config.yaml
# /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/G/config.yaml
# /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/D-Indirect/config.yaml
# /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/D/config.yaml
# /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/G/config.yaml
# /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/D-Indirect/config.yaml
# /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/D/config.yaml
# /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/G/config.yaml
# /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/D-Indirect/config.yaml
# /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/D/config.yaml
# /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/G/config.yaml
# /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/D-Indirect/config.yaml
# /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/D/config.yaml
# /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/G/config.yaml
# /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/D-Indirect/config.yaml
# /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/D/config.yaml
# /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/G/config.yaml

# %%
commands = []
for config_dir in config_dirs:
    command_start = 'python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py '
    config = load_config(config_dir)
    num_trials = config['experiment']['num_trials']
    for t in range(num_trials):
        command = command_start + config_dir + ' -t ' + str(t)
        commands.append(command)

# %%
for c in commands:
    print(c)
# Out:
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/D-Indirect/config.yaml -t 0
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/D-Indirect/config.yaml -t 1
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/D-Indirect/config.yaml -t 2
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/D-Indirect/config.yaml -t 3
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/D-Indirect/config.yaml -t 4
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/D-Indirect/config.yaml -t 5
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/D-Indirect/config.yaml -t 6
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/D-Indirect/config.yaml -t 7
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/D-Indirect/config.yaml -t 8
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/D-Indirect/config.yaml -t 9
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/D/config.yaml -t 0
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/D/config.yaml -t 1
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/D/config.yaml -t 2
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/D/config.yaml -t 3
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/D/config.yaml -t 4
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/D/config.yaml -t 5
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/D/config.yaml -t 6
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/D/config.yaml -t 7
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/D/config.yaml -t 8
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/D/config.yaml -t 9
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/G/config.yaml -t 0
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/G/config.yaml -t 1
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/G/config.yaml -t 2
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/G/config.yaml -t 3
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/G/config.yaml -t 4
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/G/config.yaml -t 5
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/G/config.yaml -t 6
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/G/config.yaml -t 7
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/G/config.yaml -t 8
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/no_fitness_bias/G/config.yaml -t 9
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/D-Indirect/config.yaml -t 0
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/D-Indirect/config.yaml -t 1
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/D-Indirect/config.yaml -t 2
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/D-Indirect/config.yaml -t 3
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/D-Indirect/config.yaml -t 4
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/D-Indirect/config.yaml -t 5
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/D-Indirect/config.yaml -t 6
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/D-Indirect/config.yaml -t 7
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/D-Indirect/config.yaml -t 8
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/D-Indirect/config.yaml -t 9
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/D/config.yaml -t 0
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/D/config.yaml -t 1
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/D/config.yaml -t 2
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/D/config.yaml -t 3
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/D/config.yaml -t 4
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/D/config.yaml -t 5
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/D/config.yaml -t 6
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/D/config.yaml -t 7
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/D/config.yaml -t 8
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/D/config.yaml -t 9
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/G/config.yaml -t 0
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/G/config.yaml -t 1
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/G/config.yaml -t 2
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/G/config.yaml -t 3
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/G/config.yaml -t 4
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/G/config.yaml -t 5
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/G/config.yaml -t 6
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/G/config.yaml -t 7
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/G/config.yaml -t 8
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/3_teams_per_evaluation/G/config.yaml -t 9
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/D-Indirect/config.yaml -t 0
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/D-Indirect/config.yaml -t 1
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/D-Indirect/config.yaml -t 2
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/D-Indirect/config.yaml -t 3
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/D-Indirect/config.yaml -t 4
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/D-Indirect/config.yaml -t 5
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/D-Indirect/config.yaml -t 6
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/D-Indirect/config.yaml -t 7
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/D-Indirect/config.yaml -t 8
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/D-Indirect/config.yaml -t 9
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/D/config.yaml -t 0
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/D/config.yaml -t 1
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/D/config.yaml -t 2
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/D/config.yaml -t 3
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/D/config.yaml -t 4
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/D/config.yaml -t 5
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/D/config.yaml -t 6
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/D/config.yaml -t 7
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/D/config.yaml -t 8
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/D/config.yaml -t 9
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/G/config.yaml -t 0
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/G/config.yaml -t 1
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/G/config.yaml -t 2
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/G/config.yaml -t 3
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/G/config.yaml -t 4
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/G/config.yaml -t 5
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/G/config.yaml -t 6
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/G/config.yaml -t 7
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/G/config.yaml -t 8
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/local/fitness_bias/2_teams_per_evaluation/G/config.yaml -t 9
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/D-Indirect/config.yaml -t 0
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/D-Indirect/config.yaml -t 1
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/D-Indirect/config.yaml -t 2
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/D-Indirect/config.yaml -t 3
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/D-Indirect/config.yaml -t 4
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/D-Indirect/config.yaml -t 5
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/D-Indirect/config.yaml -t 6
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/D-Indirect/config.yaml -t 7
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/D-Indirect/config.yaml -t 8
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/D-Indirect/config.yaml -t 9
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/D/config.yaml -t 0
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/D/config.yaml -t 1
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/D/config.yaml -t 2
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/D/config.yaml -t 3
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/D/config.yaml -t 4
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/D/config.yaml -t 5
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/D/config.yaml -t 6
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/D/config.yaml -t 7
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/D/config.yaml -t 8
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/D/config.yaml -t 9
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/G/config.yaml -t 0
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/G/config.yaml -t 1
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/G/config.yaml -t 2
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/G/config.yaml -t 3
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/G/config.yaml -t 4
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/G/config.yaml -t 5
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/G/config.yaml -t 6
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/G/config.yaml -t 7
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/G/config.yaml -t 8
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/no_fitness_bias/G/config.yaml -t 9
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/D-Indirect/config.yaml -t 0
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/D-Indirect/config.yaml -t 1
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/D-Indirect/config.yaml -t 2
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/D-Indirect/config.yaml -t 3
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/D-Indirect/config.yaml -t 4
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/D-Indirect/config.yaml -t 5
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/D-Indirect/config.yaml -t 6
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/D-Indirect/config.yaml -t 7
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/D-Indirect/config.yaml -t 8
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/D-Indirect/config.yaml -t 9
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/D/config.yaml -t 0
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/D/config.yaml -t 1
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/D/config.yaml -t 2
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/D/config.yaml -t 3
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/D/config.yaml -t 4
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/D/config.yaml -t 5
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/D/config.yaml -t 6
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/D/config.yaml -t 7
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/D/config.yaml -t 8
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/D/config.yaml -t 9
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/G/config.yaml -t 0
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/G/config.yaml -t 1
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/G/config.yaml -t 2
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/G/config.yaml -t 3
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/G/config.yaml -t 4
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/G/config.yaml -t 5
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/G/config.yaml -t 6
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/G/config.yaml -t 7
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/G/config.yaml -t 8
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/3_teams_per_evaluation/G/config.yaml -t 9
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/D-Indirect/config.yaml -t 0
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/D-Indirect/config.yaml -t 1
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/D-Indirect/config.yaml -t 2
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/D-Indirect/config.yaml -t 3
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/D-Indirect/config.yaml -t 4
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/D-Indirect/config.yaml -t 5
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/D-Indirect/config.yaml -t 6
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/D-Indirect/config.yaml -t 7
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/D-Indirect/config.yaml -t 8
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/D-Indirect/config.yaml -t 9
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/D/config.yaml -t 0
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/D/config.yaml -t 1
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/D/config.yaml -t 2
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/D/config.yaml -t 3
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/D/config.yaml -t 4
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/D/config.yaml -t 5
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/D/config.yaml -t 6
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/D/config.yaml -t 7
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/D/config.yaml -t 8
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/D/config.yaml -t 9
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/G/config.yaml -t 0
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/G/config.yaml -t 1
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/G/config.yaml -t 2
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/G/config.yaml -t 3
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/G/config.yaml -t 4
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/G/config.yaml -t 5
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/G/config.yaml -t 6
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/G/config.yaml -t 7
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/G/config.yaml -t 8
# python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py /home/gonzaeve/influence-multi-objective/results/captain_c/observations/global/fitness_bias/2_teams_per_evaluation/G/config.yaml -t 9

# %%
file_dirs = []

spacer = 'trials'
batch_dir_root = '~/influence-multi-objective/sbatch/aug_29_2024/'
batch_dir = batch_dir_root+spacer

for c in commands:
    experiment_name = c.split(' ')[2].replace('/', '.')[49:-12]
    trial_num = c.split(' ')[-1]
    file_name = experiment_name +'.'+trial_num+'.sh'
    file_dir = batch_dir + '/' + file_name
    file_dirs.append(file_dir)

# %%
print(batch_dir)
# Out:
# ~/influence-multi-objective/sbatch/aug_29_2024/trials

# %%
# Define the string you want to write
file_str_start = \
"""#!/bin/bash
#SBATCH --time=0-12:00:00
#SBATCH --constraint=skylake
#SBATCH --mem=8G
#SBATCH -c 4

module load python/3.10
source ~/venv/influence/bin/activate

"""
if not os.path.exists(os.path.expanduser(batch_dir)):
    os.makedirs(os.path.expanduser(batch_dir))
for c, f in zip(commands, file_dirs):
    file_str = file_str_start + '\n' + c + '\n'
    with open(os.path.expanduser(f), 'w') as file:
        file.write(file_str)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 17
#      15 for c, f in zip(commands, file_dirs):
#      16     file_str = file_str_start + '\n' + c + '\n'
# ---> 17     with open(os.path.expanduser(f), 'w') as file:
#      18         file.write(file_str)
#
# File ~/venv/basic/lib/python3.10/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/gonzaeve/influence-multi-objective/sbatch/aug_29_2024/trials/captain_c.observations.local.no_fitness_bias.D-Indirect.0.sh'

# %%
batch_commands = []

for f in file_dirs:
    batch_commands.append('sbatch '+f)

batch_file_str = '\n'.join(batch_commands)+'\n'
with open(os.path.expanduser(batch_dir_root+'/sbatch.sh'), 'w') as file:
    file.write(batch_file_str)
