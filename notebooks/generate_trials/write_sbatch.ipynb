# %%
import os
from influence_moo.config import load_config, contractuser

top_dir = '~/influence-multi-objective/results/mini-generated'
batch_dir_root = '~/influence-multi-objective/sbatch/mini-generated-test/'

# Define the string you want to write
batch_file_start = [
    "#!/bin/bash",
    "#SBATCH --time=2-00:00:00",
    "#SBATCH --constraint=skylake",
    "#SBATCH --mem=8G",
    "#SBATCH -c 4",
    "",
    "module load python/3.10",
    "source ~/venv/influence/bin/activate",
    "",
    ""
]

file_str_start = '\n'.join(batch_file_start)

config_dirs = []
for dirpath, _, filenames in os.walk(os.path.expanduser(top_dir)):
    for filename in filenames:
        if filename == 'config.yaml':
            config_dir = contractuser(dirpath)+'/config.yaml'
            config_dirs.append(config_dir)

commands = []
for config_dir in config_dirs:
    command_start = 'python ~/influence-multi-objective/influence_moo/influence_moo/run_cli.py '
    config = load_config(config_dir)
    num_trials = config['experiment']['num_trials']
    for t in range(num_trials):
        command = command_start + config_dir + ' -t ' + str(t)
        commands.append(command)

file_dirs = []

spacer = 'trials'
batch_dir = batch_dir_root+spacer

for c in commands:
    experiment_name = c.split(' ')[2].replace('/', '.').replace('~.influence-multi-objective.results.', '').replace('.config.yaml','')
    trial_num = c.split(' ')[-1]
    file_name = experiment_name +'.'+trial_num+'.sh'
    file_dir = batch_dir + '/' + file_name
    file_dirs.append(file_dir)

print(file_dirs)

if not os.path.exists(os.path.expanduser(batch_dir)):
    os.makedirs(os.path.expanduser(batch_dir))
for c, f in zip(commands, file_dirs):
    file_str = file_str_start + '\n' + c + '\n'
    with open(os.path.expanduser(f), 'w') as file:
        file.write(file_str)

batch_commands = []

for f in file_dirs:
    batch_commands.append('sbatch '+f)

batch_file_str = '\n'.join(batch_commands)+'\n'
with open(os.path.expanduser(batch_dir_root+'/sbatch.sh'), 'w') as file:
    file.write(batch_file_str)
# Out:
# ['~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D-Indirect-Traj.0.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D-Indirect-Traj.1.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D-Indirect-Traj.2.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D-Indirect-Traj.3.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D-Indirect-Traj.4.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D-Indirect-Traj.5.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D-Indirect-Traj.6.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D-Indirect-Traj.7.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D-Indirect-Traj.8.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D-Indirect-Traj.9.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D-Indirect-Traj.10.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D-Indirect-Traj.11.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D-Indirect-Traj.12.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D-Indirect-Traj.13.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D-Indirect-Traj.14.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D-Indirect-Traj.15.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D-Indirect-Traj.16.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D-Indirect-Traj.17.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D-Indirect-Traj.18.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D-Indirect-Traj.19.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D.0.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D.1.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D.2.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D.3.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D.4.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D.5.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D.6.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D.7.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D.8.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D.9.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D.10.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D.11.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D.12.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D.13.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D.14.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D.15.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D.16.sh', '~/influence-multi-objective/sbatch/mini-generated-test/trials/mini-generated.simple_d.D.17.sh', '~/influence-multi-objective/sbatch/mini-generated-te ...
